# %% [markdown]
# # Use inceptionv4 and multiple input

# %% [markdown]
# # 1. Data Clean

# %% [markdown]
# ## Define data clean function
# if you need to do zero center, you should use data_normal rather than data_clean.

# %%
def data_normal(X_,y_,is_training):
    '''Create 3-channel 'images'. Return rescale-normalised images.'''
    images_1 = []
    images_2 = []
    avergae_bright=[]
    for i, row in X_.iterrows():
        # Formulate the bands as 75x75 arrays
        band_1 = np.array(row['band_1']).reshape(75, 75)
        band_2 = np.array(row['band_2']).reshape(75, 75)
        # Rescale
        hh = (band_1 - band_1.min()) / (band_1.max() - band_1.min())
        hv = (band_2 - band_2.min()) / (band_2.max() - band_2.min())

        images_1.append(hh)
        images_2.append(hv)
        
    images_1=np.array([band[:,:,np.newaxis] for band in images_1])
    images_2=np.array([band[:,:,np.newaxis] for band in images_2])
    X_data_angle=np.reshape(np.sin(X_["inc_angle"]),(X_["inc_angle"].shape[0],1))
#     X_data_ave=np.reshape(avergae_bright,(len(avergae_bright),1))
#     X_data_plus=np.concatenate([X_data_angle[:, np.newaxis], 
#                               X_data_ave[:, np.newaxis]], 
#                               axis=2)
    X_data_plus=np.concatenate([X_data_angle[:, np.newaxis]], 
                              axis=2)
    X_data_plus=X_data_plus.reshape(X_data_plus.shape[0],X_data_plus.shape[2])
    if is_training:
        y_data = keras.utils.to_categorical(y_, num_classes)
    else:
        y_data = None
    return (images_1,images_2,X_data_plus,y_data)

# Define threadsafe_generator
# If we want to use data augmentation in training process,we have to use @threadsafe_generator to make any generator thread safe.

# Note: A non thread safe generator in a multithreaded envrionment just crashes, yieldsing a 'ValueError: generator already executing' error.You can try it yourself by removing the @threadsafe_generator decorator from count().

# Also, since we have to use multiple generators to feed both the image data and the angle data, we have to define our own generator: generator_img_angle()

import threading
from keras.preprocessing.image import ImageDataGenerator

class threadsafe_iter:
    """Takes an iterator/generator and makes it thread-safe by
    serializing call to the `next` method of given iterator/generator.
    """
    def __init__(self, it):
        self.it = it
        self.lock = threading.Lock()
 
    def __iter__(self):
        return self
 
    def __next__(self):
        with self.lock:
            return self.it.__next__()
 
def threadsafe_generator(f):
    """A decorator that takes a generator function and makes it thread-safe.
    """
    def g(*a, **kw):
        return threadsafe_iter(f(*a, **kw))
    return g
 
#Define data clean function
# if you need to do zero center, you should use data_normal rather than data_clean.

import matplotlib.pyplot as plt
def plt_images(X_images):
    plt.imshow(X_images,cmap = plt.cm.gray)

def data_normal(X_,y_,is_training):
    '''Create 3-channel 'images'. Return rescale-normalised images.'''
    images_1 = []
    images_2 = []
    avergae_bright=[]
    index=1
    for i, row in X_.iterrows():
        # Formulate the bands as 75x75 arrays
        band_1 = np.array(row['band_1']).reshape(75, 75)
        band_2 = np.array(row['band_2']).reshape(75, 75)
#         avei=(np.sum(band_1)+np.sum(band_2))/(band_1.shape[0]+band_2.shape[0])
        # Rescale
        r = (band_1 - band_1.min()) / (band_1.max() - band_1.min())
        g = (band_2 - band_2.min()) / (band_2.max() - band_2.min())
        
        images_1.append(r[:,:,np.newaxis])
        images_2.append(g[:,:,np.newaxis])
#         avergae_bright.append(avei)
        
    X_data_angle=np.reshape(np.sin(X_["inc_angle"]),(X_["inc_angle"].shape[0],1))
    X_data_plus=np.concatenate([X_data_angle[:, np.newaxis]], 
                              axis=2)
    X_data_plus=X_data_plus.reshape(X_data_plus.shape[0],X_data_plus.shape[2])
    if is_training:
        y_data = keras.utils.to_categorical(y_, num_classes)
    else:
        y_data = None

    return (np.array(images_1),np.array(images_2),X_data_plus,y_data)


# Define threadsafe_generator
# If we want to use data augmentation in training process,we have to use @threadsafe_generator to make any generator thread safe.

# Note: A non thread safe generator in a multithreaded envrionment just crashes, yieldsing a 'ValueError: generator already executing' error.You can try it yourself by removing the @threadsafe_generator decorator from count().

# Also, since we have to use multiple generators to feed both the image data and the angle data, we have to define our own generator: generator_img_angle()
import threading
from keras.preprocessing.image import ImageDataGenerator

class threadsafe_iter:
    """Takes an iterator/generator and makes it thread-safe by
    serializing call to the `next` method of given iterator/generator.
    """
    def __init__(self, it):
        self.it = it
        self.lock = threading.Lock()
 
    def __iter__(self):
        return self
 
    def __next__(self):
        with self.lock:
            return self.it.__next__()
 
def threadsafe_generator(f):
    """A decorator that takes a generator function and makes it thread-safe.
    """
    def g(*a, **kw):
        return threadsafe_iter(f(*a, **kw))
    return g
 
    
@threadsafe_generator
def generator_img_plus_new( generator, X1,X2,X_plus, y, batch_size = 32 ):
    SEED=816
    generator_seed = np.random.randint( SEED )
    gen_X1 = generator.flow( X1, y, 
                             batch_size = batch_size, seed = generator_seed )
    gen_X2 = generator.flow( X1, X2, 
                             batch_size = batch_size, seed = generator_seed )
    gen_X3 = generator.flow( X1, X_plus, 
                             batch_size = batch_size, seed = generator_seed )

    while True:
        X1i = gen_X1.next()
        X2i = gen_X2.next()
        X3i = gen_X3.next()
        yield [ X1i[0], X2i[1],X3i[1] ], X1i[1]
    
#load data
import numpy as np
# %matplotlib inline
from sklearn.model_selection import train_test_split
import pandas as pd
import json
import keras
import math
#Load the data.
train = pd.read_json("../input/train.json")

#use mean of angle to replace "na"
inc_angle = train.inc_angle.replace('na',0)
idx=np.where(inc_angle==0)
inc_angle = inc_angle.drop(idx[0])
inc_mean=np.mean(inc_angle)
train.inc_angle = train.inc_angle.replace('na',inc_mean)


#Do Data Cleaning on training data and validation data
num_classes=2


y_train=train['is_iceberg']

X_train_cv, X_valid, y_train_cv, y_valid = train_test_split(train,y_train, random_state=1, train_size=0.75)
# X_train_cv,X_train_angle,y_train_cv=data_clean(X_train_cv,y_train_cv,is_training=True)
# X_valid,X_valid_angle,y_valid=data_clean(X_valid,y_valid,is_training=True)

X_train_1,X_train_2,X_train_plus,y_train_cv=data_normal(X_train_cv,y_train_cv,is_training=True)
X_valid_1,X_valid_2,X_valid_plus,y_valid=data_normal(X_valid,y_valid,is_training=True)

print(X_train_1.shape,X_train_2.shape,X_train_plus.shape,y_train_cv.shape)
print(X_valid_1.shape,X_valid_2.shape,X_valid_plus.shape,y_valid.shape)
        
        
#load data
import numpy as np
# %matplotlib inline
from sklearn.model_selection import train_test_split
import pandas as pd
import json
import keras
import math
#Load the data.
train = pd.read_json("../input/train.json")

#use mean of angle to replace "na"
inc_angle = train.inc_angle.replace('na',0)
idx=np.where(inc_angle==0)
inc_angle = inc_angle.drop(idx[0])
inc_mean=np.mean(inc_angle)
train.inc_angle = train.inc_angle.replace('na',inc_mean)
# train=train.drop(idx[0])
# train.inc_angle = train.inc_angle.replace('na',0)
    
                      
#Do Data Cleaning on training data and validation data                   
num_classes=2


y_train=train['is_iceberg']

X_train_cv, X_valid, y_train_cv, y_valid = train_test_split(train,y_train, random_state=1, train_size=0.75)
# X_train_cv,X_train_angle,y_train_cv=data_clean(X_train_cv,y_train_cv,is_training=True)
# X_valid,X_valid_angle,y_valid=data_clean(X_valid,y_valid,is_training=True)

X_train_1,X_train_2,X_train_plus,y_train_cv=data_normal(X_train_cv,y_train_cv,is_training=True)
X_valid_1,X_valid_2,X_valid_plus,y_valid=data_normal(X_valid,y_valid,is_training=True)

print(X_train_1.shape,X_train_2.shape,X_train_plus.shape,y_train_cv.shape)
print(X_valid_1.shape,X_valid_2.shape,X_valid_plus.shape,y_valid.shape)
# Out:
# /home/cv/miniconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# /home/cv/miniconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# (1203, 75, 75, 1) (1203, 75, 75, 1) (1203, 1) (1203, 2)
# (401, 75, 75, 1) (401, 75, 75, 1) (401, 1) (401, 2)
# (1203, 75, 75, 1) (1203, 75, 75, 1) (1203, 1) (1203, 2)
# (401, 75, 75, 1) (401, 75, 75, 1) (401, 1) (401, 2)

# %% [markdown]
# # 2. Train model
#
# If we use data augmentaion, use the model.fit_generator version, otherwise use model.fit

# %%
from keras.applications.vgg16 import VGG16

from keras.applications.densenet import DenseNet
from keras.preprocessing import image
from keras.models import Model
from keras.models import load_model 
from keras.layers import Dense, GlobalAveragePooling2D
from keras.layers import Conv2D, MaxPooling2D,Dense, Activation, Flatten
from keras.layers.normalization import BatchNormalization
from keras.layers import Dropout
from keras import regularizers
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input
import tensorflow as tf

import math
import os
import keras

#Macro defined
batch_size =32
num_classes =2
epochs =300
batch_num_per_epoch=math.ceil(X_train_cv.shape[0]/batch_size)
batch_num_val=math.ceil(X_valid.shape[0]/batch_size)
data_augmentation = True
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_iceberg_transe.h5'
filepath="keras_iceberg_transe_epoch_mymodel.h5"


def dense_block(inputs,filter_num):
    x=Dense(filter_num,kernel_initializer='he_normal',kernel_regularizer=regularizers.l2(0.1))(inputs)
    x=keras.layers.advanced_activations.LeakyReLU(alpha=0.01)(x)
    x=Dropout(0.4)(x)
    return x

def model_i(input_x,angle_input):
    image_out= GlobalAveragePooling2D()(input_x)
    x = keras.layers.concatenate([image_out, angle_input],axis=-1)
    x=dense_block(x,256)
    x=dense_block(x,16)
    prediction = Dense(num_classes, activation='selu',kernel_initializer='glorot_normal',
                   kernel_regularizer=regularizers.l2(0.001))(x)
    return prediction
# create the base pre-trained model

# #dense_net
# base_model=DenseNet(blocks=[6, 12, 48, 32],
#              include_top=False,
#              weights='imagenet',
#              input_tensor=None,
#              input_shape=None,
#              pooling=None,
#              classes=1000)
# x= base_model.output

#inception_v4
# base_model_1=keras.applications.inception_resnet_v2.InceptionResNetV2(include_top=False,weights=None, 
#                                                                       input_tensor=None, 
#                              input_shape=(75,75,1), pooling=None, classes=1000)
# x1= base_model_1.get_layer('mixed_7a').output

# base_model_2=keras.applications.inception_resnet_v2_change.InceptionResNetV2(include_top=False,weights=None, input_tensor=None, 
#                              input_shape=None, pooling=None, classes=1000)
# x2= base_model_2.get_layer('mixed_7a_2').output

#inception_v3
base_model_1=keras.applications.inception_v3.InceptionV3(include_top=False,
                                            weights=None,
                                            input_tensor=None,
                                            input_shape=(75,75,1),
                                            pooling=None,
                                            classes=1000)
main_input1= base_model_1.get_layer('mixed3').output
base_model_2=keras.applications.inception_v3_change.InceptionV3(include_top=False,
                                            weights=None,
                                            input_tensor=None,
                                            input_shape=(75,75,1),
                                            pooling=None,
                                            classes=1000)
main_input2= base_model_2.get_layer('mixed2_2').output

#vgg16
# base_model=keras.applications.vgg16.VGG16(include_top=False,weights='imagenet',
#                                 input_tensor=None, input_shape=None,
#                                 pooling=None,
#                                 classes=1)
# x= base_model.get_layer('block4_pool').output

#vgg-19
# base_model=keras.applications.vgg19.VGG19(include_top=False, weights='imagenet',
#                                 input_tensor=None, input_shape=None,
#                                 pooling=None,
#                                 classes=1000)
# x= base_model.get_layer('block5_pool').output

#xception
# base_model=keras.applications.xception.Xception(include_top=False, weights='imagenet',
#                                     input_tensor=None, input_shape=None,
#                                     pooling=None, classes=1000)
# x= base_model.get_layer('block14_sepconv1_act').output

#resnet-50
# base_model=keras.applications.resnet50.ResNet50(include_top=False, weights='imagenet',
#                                 input_tensor=None, input_shape=None,
#                                 pooling=None,
#                                 classes=1000)
# x= base_model.get_layer('avg_pool').output

plus_input = Input(shape=(1,), name='plus_input')
x1_pre=model_i(main_input1,plus_input)
x2_pre=model_i(main_input2,plus_input)

x_pre=keras.layers.concatenate([x1_pre,x2_pre])
x_pre=dense_block(x_pre,16)
predictions = Dense(num_classes, activation='softmax',name='main_output',
                    kernel_regularizer=regularizers.l2(0.001),
                    kernel_initializer='glorot_normal')(x1_pre)


# this is the model we will train
model = Model(inputs=[base_model_1.input,base_model_2.input, plus_input], outputs=predictions)

# compile the model (should be done *after* setting layers to non-trainable)
opt=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
model.compile(optimizer=opt, loss='categorical_crossentropy',metrics=['accuracy'])

#input data

# Fit the model on the batches generated by datagen.flow().
# model.fit([X_train_1,X_train_2, X_train_plus],y_train_cv,
#           validation_data=([X_valid_1,X_valid_2,X_valid_plus],y_valid),
#           epochs=epochs, batch_size=batch_size,
#           callbacks=[keras.callbacks.ModelCheckpoint(filepath,
#                                                         monitor='val_acc',
#                                                         verbose=0,
#                                                         save_best_only=True, 
#                                                         mode='auto')])

image_augmentation = ImageDataGenerator( rotation_range = 20,
                                         horizontal_flip = True,
                                         vertical_flip = True,
                                         width_shift_range = .3,
                                         height_shift_range =.3,
                                         zoom_range = .1 )

train_generator = generator_img_plus_new( image_augmentation, X_train_1,X_train_2,
                                X_train_plus, y_train_cv, 
                                batch_size = batch_size)
model.fit_generator(train_generator,epochs=epochs,
                    validation_data=([X_valid_1,X_valid_2,X_valid_plus],y_valid),
#                   validation_data=generator_img_angle(X_valid,X_valid_angle,y_valid,
#                                                       batch_size,is_training=True),
                    validation_steps=batch_num_val,
                    workers=4,
                    steps_per_epoch=batch_num_per_epoch,
                    # 该回调函数将在每个epoch后保存模型到filepath
                    callbacks=[keras.callbacks.ModelCheckpoint(filepath,
                                                               monitor='val_acc',
                                                               verbose=0,
                                                               save_best_only=True, 
                                                               mode='auto')])

# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)

# Score trained model.
scores = model.evaluate([X_valid_1,X_valid_2, X_valid_plus],y_valid, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Epoch 1/300

# %% [markdown]
# ## validation check

# %%
import keras
# Score trained model.
scores = model.evaluate([X_valid_1,X_valid_2, X_valid_plus],y_valid, verbose=1)
# batch_size=32
# batch_num_val=math.ceil(X_valid.shape[0]/batch_size)
# scores = model.evaluate_generator(generator_img_plus(X_valid, X_valid_plus, y_valid,batch_size=batch_size),
#                                   steps=batch_num_val)

print("validation accuracy:",scores)
# Out:
# 401/401 [==============================] - 1s 3ms/step
# validation accuracy: [0.71279475397599901, 0.85536159660453515]

# %% [markdown]
# # 3.Predict

# %% [markdown]
# ## Load a pretrained model

# %%
from keras.models import load_model
model_path="../iceberg_code/keras_iceberg_transe_epoch_mymodel.h5"
model = load_model(model_path)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## predict

# %%
import json
import numpy as np
import pandas as pd
import math

cut_set_num=10
lenth_test=8424
num_classes=2
is_training=False
test_path="../input/test_cut/"
batch_size=32


predicted_test=[]
result_max=[]
test_id=[]


for ci in range(cut_set_num):
    test_pathi=test_path+"test%d.json"%ci
    test_json_str = open(test_pathi, 'r').readlines()[0]
    test=pd.read_json(test_json_str)
    
    #use mean of angle to replace "na"
    inc_angle = test.inc_angle.replace('na',0)
    idx=np.where(inc_angle==0)
    inc_angle = inc_angle.drop(idx[0])
    inc_mean=np.mean(inc_angle)
    test.inc_angle = test.inc_angle.replace('na',inc_mean)
#     test= test.drop(idx[0])
#     test.inc_angle = test.inc_angle.replace('na',0)
   
    X_test,X_test_plus,y_test=data_normal(X_=test,y_=None,is_training=False)
    batch_num_predic=math.ceil(X_test.shape[0]/batch_size)
#     print(X_test.shape[0],batch_num_predic)
    #发现一个问题,steps总是比我设置的多出10
    predicted_testi=model.predict([X_test,X_test_plus])
    
#     predicted_testi=model.predict_generator(generator_img_angle(X11=X_test,
#                                                                 X2=X_test_angle, 
#                                                                 Y=None,
#                                                                 batch_size=batch_size,
#                                                                 is_training=False),
#                                             steps=batch_num_predic)
    
    test_id.extend(test["id"])
    predicted_testi=predicted_testi.reshape(predicted_testi.shape[0],2)
    for index in range(len(predicted_testi)):
        predicted_test.append(predicted_testi[index][1])
    result_max.extend( np.argmax(predicted_testi, axis = 1) )
    
    print("batch%d has finished!"%ci)
    print()
# Out:
# /home/cv/miniconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# batch0 has finished!
#
# batch1 has finished!
#
# batch2 has finished!
#
# batch3 has finished!
#
# batch4 has finished!
#
# batch5 has finished!
#
# batch6 has finished!
#
# batch7 has finished!
#
# batch8 has finished!
#
# batch9 has finished!

# %%
# save result
submission = pd.DataFrame()
print(len(test_id),len(result_max),len(predicted_test))
submission['id']=test_id
submission['is_iceberg']=result_max
submission.to_csv('sub.csv', index=False)
# save probablity

submission['is_iceberg']=predicted_test
submission.to_csv('plus_inceptionv3.csv', index=False,float_format="%.6lf")
# Out:
# 8424 8424 8424

# %%
print(base_model_1.summary())
from keras.utils import plot_model
plot_model(base_model_1, to_file='model.png')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_895 (Conv2D)             (None, None, None, 3 864         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_815 (BatchN (None, None, None, 3 96          conv2d_895[0][0]
# __________________________________________________________________________________________________
# activation_893 (Activation)     (None, None, None, 3 0           batch_normalization_815[0][0]
# __________________________________________________________________________________________________
# conv2d_896 (Conv2D)             (None, None, None, 3 9216        activation_893[0][0]
# __________________________________________________________________________________________________
# batch_normalization_816 (BatchN (None, None, None, 3 96          conv2d_896[0][0]
# __________________________________________________________________________________________________
# activation_894 (Activation)     (None, None, None, 3 0           batch_normalization_816[0][0]
# __________________________________________________________________________________________________
# conv2d_897 (Conv2D)             (None, None, None, 6 18432       activation_894[0][0]
# __________________________________________________________________________________________________
# batch_normalization_817 (BatchN (None, None, None, 6 192         conv2d_897[0][0]
# __________________________________________________________________________________________________
# activation_895 (Activation)     (None, None, None, 6 0           batch_normalization_817[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, None, None, 6 0           activation_895[0][0]
# __________________________________________________________________________________________________
# conv2d_898 (Conv2D)             (None, None, None, 8 5120        max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_818 (BatchN (None, None, None, 8 240         conv2d_898[0][0]
# __________________________________________________________________________________________________
# activation_896 (Activation)     (None, None, None, 8 0           batch_normalization_818[0][0]
# __________________________________________________________________________________________________
# conv2d_899 (Conv2D)             (None, None, None, 1 138240      activation_896[0][0]
# __________________________________________________________________________________________________
# batch_normalization_819 (BatchN (None, None, None, 1 576         conv2d_899[0][0]
# __________________________________________________________________________________________________
# activation_897 (Activation)     (None, None, None, 1 0           batch_normalization_819[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, None, None, 1 0           activation_897[0][0]
# __________________________________________________________________________________________________
# conv2d_903 (Conv2D)             (None, None, None, 6 12288       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_823 (BatchN (None, None, None, 6 192         conv2d_903[0][0]
# __________________________________________________________________________________________________
# activation_901 (Activation)     (None, None, None, 6 0           batch_normalization_823[0][0]
# __________________________________________________________________________________________________
# conv2d_901 (Conv2D)             (None, None, None, 4 9216        max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_904 (Conv2D)             (None, None, None, 9 55296       activation_901[0][0]
# __________________________________________________________________________________________________
# batch_normalization_821 (BatchN (None, None, None, 4 144         conv2d_901[0][0]
# __________________________________________________________________________________________________
# batch_normalization_824 (BatchN (None, None, None, 9 288         conv2d_904[0][0]
# __________________________________________________________________________________________________
# activation_899 (Activation)     (None, None, None, 4 0           batch_normalization_821[0][0]
# __________________________________________________________________________________________________
# activation_902 (Activation)     (None, None, None, 9 0           batch_normalization_824[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, None, None, 1 0           max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_900 (Conv2D)             (None, None, None, 9 18432       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_902 (Conv2D)             (None, None, None, 6 76800       activation_899[0][0]
# __________________________________________________________________________________________________
# conv2d_905 (Conv2D)             (None, None, None, 9 82944       activation_902[0][0]
# __________________________________________________________________________________________________
# conv2d_906 (Conv2D)             (None, None, None, 6 12288       average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_820 (BatchN (None, None, None, 9 288         conv2d_900[0][0]
# __________________________________________________________________________________________________
# batch_normalization_822 (BatchN (None, None, None, 6 192         conv2d_902[0][0]
# __________________________________________________________________________________________________
# batch_normalization_825 (BatchN (None, None, None, 9 288         conv2d_905[0][0]
# __________________________________________________________________________________________________
# batch_normalization_826 (BatchN (None, None, None, 6 192         conv2d_906[0][0]
# __________________________________________________________________________________________________
# activation_898 (Activation)     (None, None, None, 9 0           batch_normalization_820[0][0]
# __________________________________________________________________________________________________
# activation_900 (Activation)     (None, None, None, 6 0           batch_normalization_822[0][0]
# __________________________________________________________________________________________________
# activation_903 (Activation)     (None, None, None, 9 0           batch_normalization_825[0][0]
# __________________________________________________________________________________________________
# activation_904 (Activation)     (None, None, None, 6 0           batch_normalization_826[0][0]
# __________________________________________________________________________________________________
# mixed_5b (Concatenate)          (None, None, None, 3 0           activation_898[0][0]
#                                                                  activation_900[0][0]
#                                                                  activation_903[0][0]
#                                                                  activation_904[0][0]
# __________________________________________________________________________________________________
# conv2d_910 (Conv2D)             (None, None, None, 3 10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_830 (BatchN (None, None, None, 3 96          conv2d_910[0][0]
# __________________________________________________________________________________________________
# activation_908 (Activation)     (None, None, None, 3 0           batch_normalization_830[0][0]
# __________________________________________________________________________________________________
# conv2d_908 (Conv2D)             (None, None, None, 3 10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_911 (Conv2D)             (None, None, None, 4 13824       activation_908[0][0]
# __________________________________________________________________________________________________
# batch_normalization_828 (BatchN (None, None, None, 3 96          conv2d_908[0][0]
# __________________________________________________________________________________________________
# batch_normalization_831 (BatchN (None, None, None, 4 144         conv2d_911[0][0]
# __________________________________________________________________________________________________
# activation_906 (Activation)     (None, None, None, 3 0           batch_normalization_828[0][0]
# __________________________________________________________________________________________________
# activation_909 (Activation)     (None, None, None, 4 0           batch_normalization_831[0][0]
# __________________________________________________________________________________________________
# conv2d_907 (Conv2D)             (None, None, None, 3 10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_909 (Conv2D)             (None, None, None, 3 9216        activation_906[0][0]
# __________________________________________________________________________________________________
# conv2d_912 (Conv2D)             (None, None, None, 6 27648       activation_909[0][0]
# __________________________________________________________________________________________________
# batch_normalization_827 (BatchN (None, None, None, 3 96          conv2d_907[0][0]
# __________________________________________________________________________________________________
# batch_normalization_829 (BatchN (None, None, None, 3 96          conv2d_909[0][0]
# __________________________________________________________________________________________________
# batch_normalization_832 (BatchN (None, None, None, 6 192         conv2d_912[0][0]
# __________________________________________________________________________________________________
# activation_905 (Activation)     (None, None, None, 3 0           batch_normalization_827[0][0]
# __________________________________________________________________________________________________
# activation_907 (Activation)     (None, None, None, 3 0           batch_normalization_829[0][0]
# __________________________________________________________________________________________________
# activation_910 (Activation)     (None, None, None, 6 0           batch_normalization_832[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed (Concatenate)   (None, None, None, 1 0           activation_905[0][0]
#                                                                  activation_907[0][0]
#                                                                  activation_910[0][0]
# __________________________________________________________________________________________________
# block35_1_conv (Conv2D)         (None, None, None, 3 41280       block35_1_mixed[0][0]
# __________________________________________________________________________________________________
# block35_1 (Lambda)              (None, None, None, 3 0           mixed_5b[0][0]
#                                                                  block35_1_conv[0][0]
# __________________________________________________________________________________________________
# block35_1_ac (Activation)       (None, None, None, 3 0           block35_1[0][0]
# __________________________________________________________________________________________________
# conv2d_916 (Conv2D)             (None, None, None, 3 10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_836 (BatchN (None, None, None, 3 96          conv2d_916[0][0]
# __________________________________________________________________________________________________
# activation_914 (Activation)     (None, None, None, 3 0           batch_normalization_836[0][0]
# __________________________________________________________________________________________________
# conv2d_914 (Conv2D)             (None, None, None, 3 10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_917 (Conv2D)             (None, None, None, 4 13824       activation_914[0][0]
# __________________________________________________________________________________________________
# batch_normalization_834 (BatchN (None, None, None, 3 96          conv2d_914[0][0]
# __________________________________________________________________________________________________
# batch_normalization_837 (BatchN (None, None, None, 4 144         conv2d_917[0][0]
# __________________________________________________________________________________________________
# activation_912 (Activation)     (None, None, None, 3 0           batch_normalization_834[0][0]
# __________________________________________________________________________________________________
# activation_915 (Activation)     (None, None, None, 4 0           batch_normalization_837[0][0]
# __________________________________________________________________________________________________
# conv2d_913 (Conv2D)             (None, None, None, 3 10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_915 (Conv2D)             (None, None, None, 3 9216        activation_912[0][0]
# __________________________________________________________________________________________________
# conv2d_918 (Conv2D)             (None, None, None, 6 27648       activation_915[0][0]
# __________________________________________________________________________________________________
# batch_normalization_833 (BatchN (None, None, None, 3 96          conv2d_913[0][0]
# __________________________________________________________________________________________________
# batch_normalization_835 (BatchN (None, None, None, 3 96          conv2d_915[0][0]
# __________________________________________________________________________________________________
# batch_normalization_838 (BatchN (None, None, None, 6 192         conv2d_918[0][0]
# __________________________________________________________________________________________________
# activation_911 (Activation)     (None, None, None, 3 0           batch_normalization_833[0][0]
# __________________________________________________________________________________________________
# activation_913 (Activation)     (None, None, None, 3 0           batch_normalization_835[0][0]
# __________________________________________________________________________________________________
# activation_916 (Activation)     (None, None, None, 6 0           batch_normalization_838[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed (Concatenate)   (None, None, None, 1 0           activation_911[0][0]
#                                                                  activation_913[0][0]
#                                                                  activation_916[0][0]
# __________________________________________________________________________________________________
# block35_2_conv (Conv2D)         (None, None, None, 3 41280       block35_2_mixed[0][0]
# __________________________________________________________________________________________________
# block35_2 (Lambda)              (None, None, None, 3 0           block35_1_ac[0][0]
#                                                                  block35_2_conv[0][0]
# __________________________________________________________________________________________________
# block35_2_ac (Activation)       (None, None, None, 3 0           block35_2[0][0]
# __________________________________________________________________________________________________
# conv2d_922 (Conv2D)             (None, None, None, 3 10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_842 (BatchN (None, None, None, 3 96          conv2d_922[0][0]
# __________________________________________________________________________________________________
# activation_920 (Activation)     (None, None, None, 3 0           batch_normalization_842[0][0]
# __________________________________________________________________________________________________
# conv2d_920 (Conv2D)             (None, None, None, 3 10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_923 (Conv2D)             (None, None, None, 4 13824       activation_920[0][0]
# __________________________________________________________________________________________________
# batch_normalization_840 (BatchN (None, None, None, 3 96          conv2d_920[0][0]
# __________________________________________________________________________________________________
# batch_normalization_843 (BatchN (None, None, None, 4 144         conv2d_923[0][0]
# __________________________________________________________________________________________________
# activation_918 (Activation)     (None, None, None, 3 0           batch_normalization_840[0][0]
# __________________________________________________________________________________________________
# activation_921 (Activation)     (None, None, None, 4 0           batch_normalization_843[0][0]
# __________________________________________________________________________________________________
# conv2d_919 (Conv2D)             (None, None, None, 3 10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_921 (Conv2D)             (None, None, None, 3 9216        activation_918[0][0]
# __________________________________________________________________________________________________
# conv2d_924 (Conv2D)             (None, None, None, 6 27648       activation_921[0][0]
# __________________________________________________________________________________________________
# batch_normalization_839 (BatchN (None, None, None, 3 96          conv2d_919[0][0]
# __________________________________________________________________________________________________
# batch_normalization_841 (BatchN (None, None, None, 3 96          conv2d_921[0][0]
# __________________________________________________________________________________________________
# batch_normalization_844 (BatchN (None, None, None, 6 192         conv2d_924[0][0]
# __________________________________________________________________________________________________
# activation_917 (Activation)     (None, None, None, 3 0           batch_normalization_839[0][0]
# __________________________________________________________________________________________________
# activation_919 (Activation)     (None, None, None, 3 0           batch_normalization_841[0][0]
# __________________________________________________________________________________________________
# activation_922 (Activation)     (None, None, None, 6 0           batch_normalization_844[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed (Concatenate)   (None, None, None, 1 0           activation_917[0][0]
#                                                                  activation_919[0][0]
#                                                                  activation_922[0][0]
# __________________________________________________________________________________________________
# block35_3_conv (Conv2D)         (None, None, None, 3 41280       block35_3_mixed[0][0]
# __________________________________________________________________________________________________
# block35_3 (Lambda)              (None, None, None, 3 0           block35_2_ac[0][0]
#                                                                  block35_3_conv[0][0]
# __________________________________________________________________________________________________
# block35_3_ac (Activation)       (None, None, None, 3 0           block35_3[0][0]
# __________________________________________________________________________________________________
# conv2d_928 (Conv2D)             (None, None, None, 3 10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_848 (BatchN (None, None, None, 3 96          conv2d_928[0][0]
# __________________________________________________________________________________________________
# activation_926 (Activation)     (None, None, None, 3 0           batch_normalization_848[0][0]
# __________________________________________________________________________________________________
# conv2d_926 (Conv2D)             (None, None, None, 3 10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_929 (Conv2D)             (None, None, None, 4 13824       activation_926[0][0]
# __________________________________________________________________________________________________
# batch_normalization_846 (BatchN (None, None, None, 3 96          conv2d_926[0][0]
# __________________________________________________________________________________________________
# batch_normalization_849 (BatchN (None, None, None, 4 144         conv2d_929[0][0]
# __________________________________________________________________________________________________
# activation_924 (Activation)     (None, None, None, 3 0           batch_normalization_846[0][0]
# __________________________________________________________________________________________________
# activation_927 (Activation)     (None, None, None, 4 0           batch_normalization_849[0][0]
# __________________________________________________________________________________________________
# conv2d_925 (Conv2D)             (None, None, None, 3 10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_927 (Conv2D)             (None, None, None, 3 9216        activation_924[0][0]
# __________________________________________________________________________________________________
# conv2d_930 (Conv2D)             (None, None, None, 6 27648       activation_927[0][0]
# __________________________________________________________________________________________________
# batch_normalization_845 (BatchN (None, None, None, 3 96          conv2d_925[0][0]
# __________________________________________________________________________________________________
# batch_normalization_847 (BatchN (None, None, None, 3 96          conv2d_927[0][0]
# __________________________________________________________________________________________________
# batch_normalization_850 (BatchN (None, None, None, 6 192         conv2d_930[0][0]
# __________________________________________________________________________________________________
# activation_923 (Activation)     (None, None, None, 3 0           batch_normalization_845[0][0]
# __________________________________________________________________________________________________
# activation_925 (Activation)     (None, None, None, 3 0           batch_normalization_847[0][0]
# __________________________________________________________________________________________________
# activation_928 (Activation)     (None, None, None, 6 0           batch_normalization_850[0][0]
# __________________________________________________________________________________________________
# block35_4_mixed (Concatenate)   (None, None, None, 1 0           activation_923[0][0]
#                                                                  activation_925[0][0]
#                                                                  activation_928[0][0]
# __________________________________________________________________________________________________
# block35_4_conv (Conv2D)         (None, None, None, 3 41280       block35_4_mixed[0][0]
# __________________________________________________________________________________________________
# block35_4 (Lambda)              (None, None, None, 3 0           block35_3_ac[0][0]
#                                                                  block35_4_conv[0][0]
# __________________________________________________________________________________________________
# block35_4_ac (Activation)       (None, None, None, 3 0           block35_4[0][0]
# __________________________________________________________________________________________________
# conv2d_934 (Conv2D)             (None, None, None, 3 10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_854 (BatchN (None, None, None, 3 96          conv2d_934[0][0]
# __________________________________________________________________________________________________
# activation_932 (Activation)     (None, None, None, 3 0           batch_normalization_854[0][0]
# __________________________________________________________________________________________________
# conv2d_932 (Conv2D)             (None, None, None, 3 10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_935 (Conv2D)             (None, None, None, 4 13824       activation_932[0][0]
# __________________________________________________________________________________________________
# batch_normalization_852 (BatchN (None, None, None, 3 96          conv2d_932[0][0]
# __________________________________________________________________________________________________
# batch_normalization_855 (BatchN (None, None, None, 4 144         conv2d_935[0][0]
# __________________________________________________________________________________________________
# activation_930 (Activation)     (None, None, None, 3 0           batch_normalization_852[0][0]
# __________________________________________________________________________________________________
# activation_933 (Activation)     (None, None, None, 4 0           batch_normalization_855[0][0]
# __________________________________________________________________________________________________
# conv2d_931 (Conv2D)             (None, None, None, 3 10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_933 (Conv2D)             (None, None, None, 3 9216        activation_930[0][0]
# __________________________________________________________________________________________________
# conv2d_936 (Conv2D)             (None, None, None, 6 27648       activation_933[0][0]
# __________________________________________________________________________________________________
# batch_normalization_851 (BatchN (None, None, None, 3 96          conv2d_931[0][0]
# __________________________________________________________________________________________________
# batch_normalization_853 (BatchN (None, None, None, 3 96          conv2d_933[0][0]
# __________________________________________________________________________________________________
# batch_normalization_856 (BatchN (None, None, None, 6 192         conv2d_936[0][0]
# __________________________________________________________________________________________________
# activation_929 (Activation)     (None, None, None, 3 0           batch_normalization_851[0][0]
# __________________________________________________________________________________________________
# activation_931 (Activation)     (None, None, None, 3 0           batch_normalization_853[0][0]
# __________________________________________________________________________________________________
# activation_934 (Activation)     (None, None, None, 6 0           batch_normalization_856[0][0]
# __________________________________________________________________________________________________
# block35_5_mixed (Concatenate)   (None, None, None, 1 0           activation_929[0][0]
#                                                                  activation_931[0][0]
#                                                                  activation_934[0][0]
# __________________________________________________________________________________________________
# block35_5_conv (Conv2D)         (None, None, None, 3 41280       block35_5_mixed[0][0]
# __________________________________________________________________________________________________
# block35_5 (Lambda)              (None, None, None, 3 0           block35_4_ac[0][0]
#                                                                  block35_5_conv[0][0]
# __________________________________________________________________________________________________
# block35_5_ac (Activation)       (None, None, None, 3 0           block35_5[0][0]
# __________________________________________________________________________________________________
# conv2d_940 (Conv2D)             (None, None, None, 3 10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_860 (BatchN (None, None, None, 3 96          conv2d_940[0][0]
# __________________________________________________________________________________________________
# activation_938 (Activation)     (None, None, None, 3 0           batch_normalization_860[0][0]
# __________________________________________________________________________________________________
# conv2d_938 (Conv2D)             (None, None, None, 3 10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_941 (Conv2D)             (None, None, None, 4 13824       activation_938[0][0]
# __________________________________________________________________________________________________
# batch_normalization_858 (BatchN (None, None, None, 3 96          conv2d_938[0][0]
# __________________________________________________________________________________________________
# batch_normalization_861 (BatchN (None, None, None, 4 144         conv2d_941[0][0]
# __________________________________________________________________________________________________
# activation_936 (Activation)     (None, None, None, 3 0           batch_normalization_858[0][0]
# __________________________________________________________________________________________________
# activation_939 (Activation)     (None, None, None, 4 0           batch_normalization_861[0][0]
# __________________________________________________________________________________________________
# conv2d_937 (Conv2D)             (None, None, None, 3 10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_939 (Conv2D)             (None, None, None, 3 9216        activation_936[0][0]
# __________________________________________________________________________________________________
# conv2d_942 (Conv2D)             (None, None, None, 6 27648       activation_939[0][0]
# __________________________________________________________________________________________________
# batch_normalization_857 (BatchN (None, None, None, 3 96          conv2d_937[0][0]
# __________________________________________________________________________________________________
# batch_normalization_859 (BatchN (None, None, None, 3 96          conv2d_939[0][0]
# __________________________________________________________________________________________________
# batch_normalization_862 (BatchN (None, None, None, 6 192         conv2d_942[0][0]
# __________________________________________________________________________________________________
# activation_935 (Activation)     (None, None, None, 3 0           batch_normalization_857[0][0]
# __________________________________________________________________________________________________
# activation_937 (Activation)     (None, None, None, 3 0           batch_normalization_859[0][0]
# __________________________________________________________________________________________________
# activation_940 (Activation)     (None, None, None, 6 0           batch_normalization_862[0][0]
# __________________________________________________________________________________________________
# block35_6_mixed (Concatenate)   (None, None, None, 1 0           activation_935[0][0]
#                                                                  activation_937[0][0]
#                                                                  activation_940[0][0]
# __________________________________________________________________________________________________
# block35_6_conv (Conv2D)         (None, None, None, 3 41280       block35_6_mixed[0][0]
# __________________________________________________________________________________________________
# block35_6 (Lambda)              (None, None, None, 3 0           block35_5_ac[0][0]
#                                                                  block35_6_conv[0][0]
# __________________________________________________________________________________________________
# block35_6_ac (Activation)       (None, None, None, 3 0           block35_6[0][0]
# __________________________________________________________________________________________________
# conv2d_946 (Conv2D)             (None, None, None, 3 10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_866 (BatchN (None, None, None, 3 96          conv2d_946[0][0]
# __________________________________________________________________________________________________
# activation_944 (Activation)     (None, None, None, 3 0           batch_normalization_866[0][0]
# __________________________________________________________________________________________________
# conv2d_944 (Conv2D)             (None, None, None, 3 10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_947 (Conv2D)             (None, None, None, 4 13824       activation_944[0][0]
# __________________________________________________________________________________________________
# batch_normalization_864 (BatchN (None, None, None, 3 96          conv2d_944[0][0]
# __________________________________________________________________________________________________
# batch_normalization_867 (BatchN (None, None, None, 4 144         conv2d_947[0][0]
# __________________________________________________________________________________________________
# activation_942 (Activation)     (None, None, None, 3 0           batch_normalization_864[0][0]
# __________________________________________________________________________________________________
# activation_945 (Activation)     (None, None, None, 4 0           batch_normalization_867[0][0]
# __________________________________________________________________________________________________
# conv2d_943 (Conv2D)             (None, None, None, 3 10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_945 (Conv2D)             (None, None, None, 3 9216        activation_942[0][0]
# __________________________________________________________________________________________________
# conv2d_948 (Conv2D)             (None, None, None, 6 27648       activation_945[0][0]
# __________________________________________________________________________________________________
# batch_normalization_863 (BatchN (None, None, None, 3 96          conv2d_943[0][0]
# __________________________________________________________________________________________________
# batch_normalization_865 (BatchN (None, None, None, 3 96          conv2d_945[0][0]
# __________________________________________________________________________________________________
# batch_normalization_868 (BatchN (None, None, None, 6 192         conv2d_948[0][0]
# __________________________________________________________________________________________________
# activation_941 (Activation)     (None, None, None, 3 0           batch_normalization_863[0][0]
# __________________________________________________________________________________________________
# activation_943 (Activation)     (None, None, None, 3 0           batch_normalization_865[0][0]
# __________________________________________________________________________________________________
# activation_946 (Activation)     (None, None, None, 6 0           batch_normalization_868[0][0]
# __________________________________________________________________________________________________
# block35_7_mixed (Concatenate)   (None, None, None, 1 0           activation_941[0][0]
#                                                                  activation_943[0][0]
#                                                                  activation_946[0][0]
# __________________________________________________________________________________________________
# block35_7_conv (Conv2D)         (None, None, None, 3 41280       block35_7_mixed[0][0]
# __________________________________________________________________________________________________
# block35_7 (Lambda)              (None, None, None, 3 0           block35_6_ac[0][0]
#                                                                  block35_7_conv[0][0]
# __________________________________________________________________________________________________
# block35_7_ac (Activation)       (None, None, None, 3 0           block35_7[0][0]
# __________________________________________________________________________________________________
# conv2d_952 (Conv2D)             (None, None, None, 3 10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_872 (BatchN (None, None, None, 3 96          conv2d_952[0][0]
# __________________________________________________________________________________________________
# activation_950 (Activation)     (None, None, None, 3 0           batch_normalization_872[0][0]
# __________________________________________________________________________________________________
# conv2d_950 (Conv2D)             (None, None, None, 3 10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_953 (Conv2D)             (None, None, None, 4 13824       activation_950[0][0]
# __________________________________________________________________________________________________
# batch_normalization_870 (BatchN (None, None, None, 3 96          conv2d_950[0][0]
# __________________________________________________________________________________________________
# batch_normalization_873 (BatchN (None, None, None, 4 144         conv2d_953[0][0]
# __________________________________________________________________________________________________
# activation_948 (Activation)     (None, None, None, 3 0           batch_normalization_870[0][0]
# __________________________________________________________________________________________________
# activation_951 (Activation)     (None, None, None, 4 0           batch_normalization_873[0][0]
# __________________________________________________________________________________________________
# conv2d_949 (Conv2D)             (None, None, None, 3 10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_951 (Conv2D)             (None, None, None, 3 9216        activation_948[0][0]
# __________________________________________________________________________________________________
# conv2d_954 (Conv2D)             (None, None, None, 6 27648       activation_951[0][0]
# __________________________________________________________________________________________________
# batch_normalization_869 (BatchN (None, None, None, 3 96          conv2d_949[0][0]
# __________________________________________________________________________________________________
# batch_normalization_871 (BatchN (None, None, None, 3 96          conv2d_951[0][0]
# __________________________________________________________________________________________________
# batch_normalization_874 (BatchN (None, None, None, 6 192         conv2d_954[0][0]
# __________________________________________________________________________________________________
# activation_947 (Activation)     (None, None, None, 3 0           batch_normalization_869[0][0]
# __________________________________________________________________________________________________
# activation_949 (Activation)     (None, None, None, 3 0           batch_normalization_871[0][0]
# __________________________________________________________________________________________________
# activation_952 (Activation)     (None, None, None, 6 0           batch_normalization_874[0][0]
# __________________________________________________________________________________________________
# block35_8_mixed (Concatenate)   (None, None, None, 1 0           activation_947[0][0]
#                                                                  activation_949[0][0]
#                                                                  activation_952[0][0]
# __________________________________________________________________________________________________
# block35_8_conv (Conv2D)         (None, None, None, 3 41280       block35_8_mixed[0][0]
# __________________________________________________________________________________________________
# block35_8 (Lambda)              (None, None, None, 3 0           block35_7_ac[0][0]
#                                                                  block35_8_conv[0][0]
# __________________________________________________________________________________________________
# block35_8_ac (Activation)       (None, None, None, 3 0           block35_8[0][0]
# __________________________________________________________________________________________________
# conv2d_958 (Conv2D)             (None, None, None, 3 10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_878 (BatchN (None, None, None, 3 96          conv2d_958[0][0]
# __________________________________________________________________________________________________
# activation_956 (Activation)     (None, None, None, 3 0           batch_normalization_878[0][0]
# __________________________________________________________________________________________________
# conv2d_956 (Conv2D)             (None, None, None, 3 10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_959 (Conv2D)             (None, None, None, 4 13824       activation_956[0][0]
# __________________________________________________________________________________________________
# batch_normalization_876 (BatchN (None, None, None, 3 96          conv2d_956[0][0]
# __________________________________________________________________________________________________
# batch_normalization_879 (BatchN (None, None, None, 4 144         conv2d_959[0][0]
# __________________________________________________________________________________________________
# activation_954 (Activation)     (None, None, None, 3 0           batch_normalization_876[0][0]
# __________________________________________________________________________________________________
# activation_957 (Activation)     (None, None, None, 4 0           batch_normalization_879[0][0]
# __________________________________________________________________________________________________
# conv2d_955 (Conv2D)             (None, None, None, 3 10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# ...
# conv2d_1083 (Conv2D)            (None, None, None, 1 399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1003 (Batch (None, None, None, 1 576         conv2d_1083[0][0]
# __________________________________________________________________________________________________
# activation_1081 (Activation)    (None, None, None, 1 0           batch_normalization_1003[0][0]
# __________________________________________________________________________________________________
# conv2d_1084 (Conv2D)            (None, None, None, 2 129024      activation_1081[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1004 (Batch (None, None, None, 2 672         conv2d_1084[0][0]
# __________________________________________________________________________________________________
# activation_1082 (Activation)    (None, None, None, 2 0           batch_normalization_1004[0][0]
# __________________________________________________________________________________________________
# conv2d_1082 (Conv2D)            (None, None, None, 1 399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1085 (Conv2D)            (None, None, None, 2 172032      activation_1082[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1002 (Batch (None, None, None, 1 576         conv2d_1082[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1005 (Batch (None, None, None, 2 768         conv2d_1085[0][0]
# __________________________________________________________________________________________________
# activation_1080 (Activation)    (None, None, None, 1 0           batch_normalization_1002[0][0]
# __________________________________________________________________________________________________
# activation_1083 (Activation)    (None, None, None, 2 0           batch_normalization_1005[0][0]
# __________________________________________________________________________________________________
# block8_7_mixed (Concatenate)    (None, None, None, 4 0           activation_1080[0][0]
#                                                                  activation_1083[0][0]
# __________________________________________________________________________________________________
# block8_7_conv (Conv2D)          (None, None, None, 2 933920      block8_7_mixed[0][0]
# __________________________________________________________________________________________________
# block8_7 (Lambda)               (None, None, None, 2 0           block8_6_ac[0][0]
#                                                                  block8_7_conv[0][0]
# __________________________________________________________________________________________________
# block8_7_ac (Activation)        (None, None, None, 2 0           block8_7[0][0]
# __________________________________________________________________________________________________
# conv2d_1087 (Conv2D)            (None, None, None, 1 399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1007 (Batch (None, None, None, 1 576         conv2d_1087[0][0]
# __________________________________________________________________________________________________
# activation_1085 (Activation)    (None, None, None, 1 0           batch_normalization_1007[0][0]
# __________________________________________________________________________________________________
# conv2d_1088 (Conv2D)            (None, None, None, 2 129024      activation_1085[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1008 (Batch (None, None, None, 2 672         conv2d_1088[0][0]
# __________________________________________________________________________________________________
# activation_1086 (Activation)    (None, None, None, 2 0           batch_normalization_1008[0][0]
# __________________________________________________________________________________________________
# conv2d_1086 (Conv2D)            (None, None, None, 1 399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1089 (Conv2D)            (None, None, None, 2 172032      activation_1086[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1006 (Batch (None, None, None, 1 576         conv2d_1086[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1009 (Batch (None, None, None, 2 768         conv2d_1089[0][0]
# __________________________________________________________________________________________________
# activation_1084 (Activation)    (None, None, None, 1 0           batch_normalization_1006[0][0]
# __________________________________________________________________________________________________
# activation_1087 (Activation)    (None, None, None, 2 0           batch_normalization_1009[0][0]
# __________________________________________________________________________________________________
# block8_8_mixed (Concatenate)    (None, None, None, 4 0           activation_1084[0][0]
#                                                                  activation_1087[0][0]
# __________________________________________________________________________________________________
# block8_8_conv (Conv2D)          (None, None, None, 2 933920      block8_8_mixed[0][0]
# __________________________________________________________________________________________________
# block8_8 (Lambda)               (None, None, None, 2 0           block8_7_ac[0][0]
#                                                                  block8_8_conv[0][0]
# __________________________________________________________________________________________________
# block8_8_ac (Activation)        (None, None, None, 2 0           block8_8[0][0]
# __________________________________________________________________________________________________
# conv2d_1091 (Conv2D)            (None, None, None, 1 399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1011 (Batch (None, None, None, 1 576         conv2d_1091[0][0]
# __________________________________________________________________________________________________
# activation_1089 (Activation)    (None, None, None, 1 0           batch_normalization_1011[0][0]
# __________________________________________________________________________________________________
# conv2d_1092 (Conv2D)            (None, None, None, 2 129024      activation_1089[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1012 (Batch (None, None, None, 2 672         conv2d_1092[0][0]
# __________________________________________________________________________________________________
# activation_1090 (Activation)    (None, None, None, 2 0           batch_normalization_1012[0][0]
# __________________________________________________________________________________________________
# conv2d_1090 (Conv2D)            (None, None, None, 1 399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1093 (Conv2D)            (None, None, None, 2 172032      activation_1090[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1010 (Batch (None, None, None, 1 576         conv2d_1090[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1013 (Batch (None, None, None, 2 768         conv2d_1093[0][0]
# __________________________________________________________________________________________________
# activation_1088 (Activation)    (None, None, None, 1 0           batch_normalization_1010[0][0]
# __________________________________________________________________________________________________
# activation_1091 (Activation)    (None, None, None, 2 0           batch_normalization_1013[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed (Concatenate)    (None, None, None, 4 0           activation_1088[0][0]
#                                                                  activation_1091[0][0]
# __________________________________________________________________________________________________
# block8_9_conv (Conv2D)          (None, None, None, 2 933920      block8_9_mixed[0][0]
# __________________________________________________________________________________________________
# block8_9 (Lambda)               (None, None, None, 2 0           block8_8_ac[0][0]
#                                                                  block8_9_conv[0][0]
# __________________________________________________________________________________________________
# block8_9_ac (Activation)        (None, None, None, 2 0           block8_9[0][0]
# __________________________________________________________________________________________________
# conv2d_1095 (Conv2D)            (None, None, None, 1 399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1015 (Batch (None, None, None, 1 576         conv2d_1095[0][0]
# __________________________________________________________________________________________________
# activation_1093 (Activation)    (None, None, None, 1 0           batch_normalization_1015[0][0]
# __________________________________________________________________________________________________
# conv2d_1096 (Conv2D)            (None, None, None, 2 129024      activation_1093[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1016 (Batch (None, None, None, 2 672         conv2d_1096[0][0]
# __________________________________________________________________________________________________
# activation_1094 (Activation)    (None, None, None, 2 0           batch_normalization_1016[0][0]
# __________________________________________________________________________________________________
# conv2d_1094 (Conv2D)            (None, None, None, 1 399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1097 (Conv2D)            (None, None, None, 2 172032      activation_1094[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1014 (Batch (None, None, None, 1 576         conv2d_1094[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1017 (Batch (None, None, None, 2 768         conv2d_1097[0][0]
# __________________________________________________________________________________________________
# activation_1092 (Activation)    (None, None, None, 1 0           batch_normalization_1014[0][0]
# __________________________________________________________________________________________________
# activation_1095 (Activation)    (None, None, None, 2 0           batch_normalization_1017[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, None, None, 4 0           activation_1092[0][0]
#                                                                  activation_1095[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, None, None, 2 933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, None, None, 2 0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, None, None, 1 3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, None, None, 1 4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, None, None, 1 0           conv_7b_bn[0][0]
# ==================================================================================================
# Total params: 54,336,736
# Trainable params: 54,276,192
# Non-trainable params: 60,544
# __________________________________________________________________________________________________
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/keras/utils/vis_utils.py in _check_pydot()
#      22         # to check the pydot/graphviz installation.
# ---> 23         pydot.Dot.create(pydot.Dot())
#      24     except Exception:
#
# AttributeError: 'NoneType' object has no attribute 'Dot'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-67-41e63e643a03> in <module>()
#       1 print(base_model_1.summary())
#       2 from keras.utils import plot_model
# ----> 3 plot_model(base_model_1, to_file='model.png')
#
# ~/miniconda3/lib/python3.6/site-packages/keras/utils/vis_utils.py in plot_model(model, to_file, show_shapes, show_layer_names, rankdir)
#     129             'LR' creates a horizontal plot.
#     130     """
# --> 131     dot = model_to_dot(model, show_shapes, show_layer_names, rankdir)
#     132     _, extension = os.path.splitext(to_file)
#     133     if not extension:
#
# ~/miniconda3/lib/python3.6/site-packages/keras/utils/vis_utils.py in model_to_dot(model, show_shapes, show_layer_names, rankdir)
#      50     from ..models import Sequential
#      51
# ---> 52     _check_pydot()
#      53     dot = pydot.Dot()
#      54     dot.set('rankdir', rankdir)
#
# ~/miniconda3/lib/python3.6/site-packages/keras/utils/vis_utils.py in _check_pydot()
#      25         # pydot raises a generic Exception here,
#      26         # so no specific class can be caught.
# ---> 27         raise ImportError('Failed to import pydot. You must install pydot'
#      28                           ' and graphviz for `pydotprint` to work.')
#      29
#
# ImportError: Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.
